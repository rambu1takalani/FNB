# %%
import pandas as pd

# %%
df=pd.read_csv('crime_incidents_by_category.csv')
df
# Out:
#     Geography                                Crime Category Financial Year  \
# 0          ZA                                Contact Crimes      2011/2012
# 1          ZA                                Contact Crimes      2012/2013
# 2          ZA                                Contact Crimes      2013/2014
# 3          ZA                                Contact Crimes      2014/2015
# 4          ZA                                Contact Crimes      2015/2016
# ..        ...                                           ...            ...
# 835        WC                          Aggravated Robberies      2022/2023
# 836        WC                        Contact Related Crimes      2022/2023
# 837        WC                       Property Related Crimes      2022/2023
# 838        WC                          Other Serious Crimes      2022/2023
# 839        WC  Crimes Detected as a Result of Police Action      2022/2023
#
#       Count
# 0    615935
# 1    608724
# 2    611574
# 3    616973
# ...

# %%
df.isnull().sum()
# Out:
# Geography         0
# Crime Category    0
# Financial Year    0
# Count             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Geography       840 non-null    object
#  1   Crime Category  840 non-null    object
#  2   Financial Year  840 non-null    object
#  3   Count           840 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 26.4+ KB
